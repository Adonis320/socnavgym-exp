# %%
import socnavgym
import gymnasium as gym
from socnavgym.wrappers import DiscreteActions
from socnavgym.wrappers import CardinalActions
from rl.QLearning import *
from rl.MSR import *
from rl.SR import *
from rl.SF import *
from rl.DQN import *
from rl.DSR import *
from rl.SR import *
from tqdm.auto import trange
import imageio
from utils.StateDiscretizer import *
from utils.TileCoder import *

# %%
env = gym.make("SocNavGym-v1", config="./configs/2_humans.yaml") 
env = DiscreteActions(env)

SEED = 5
EPISODES = 500

discretizer = StateDiscretizer(xy_bins=30, env=env, theta_bins=8)
# Out:
# /home/adonis/Documents/Thesis/socnavgym/SocNavGym/socnavgym/envs/utils/sngnnv2/socnav_V2_API.py:78: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.GNNmodel.load_state_dict(torch.load(((sys.argv[1]) if params_dir is None else params_dir) + '/SOCNAV_V2.tch', map_location=device))
# /home/adonis/miniconda3/envs/socnavgym/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:54: UserWarning: WARN: A Box action space maximum and minimum values are equal.
#   logger.warn("A Box action space maximum and minimum values are equal.")

# %%
learning_rate = [0.5, 0.4, 0.3, 0.2]

# %%
rewards_lr = []
length_lr = []
for lr in learning_rate:
    agent = SR(
            action_size=7,
            learning_rate=lr,
            r_learning_rate=0.2,
            gamma=0.5, epsilon=0.05, discretizer=discretizer
        )

    rewards_sr_lr = []
    length_sr_lr = []
 
    for episode in trange(EPISODES):
        obs = env.reset(seed=SEED) 
        episodes_length, episodes_rewards = agent.act(env, obs)
        length_sr_lr.append(episodes_length)
        rewards_sr_lr.append(episodes_rewards)
    
    rewards_lr.append(rewards_sr_lr)
    length_lr.append(length_sr_lr)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
def rolling_avg(x, w=20):
        return np.convolve(x, np.ones(w) / w, mode='valid')

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1)

ax.plot(rolling_avg(length_lr[0]),  linewidth=2, label=learning_rate[0])
ax.plot(rolling_avg(length_lr[1]),  linewidth=2, label=learning_rate[1])
ax.plot(rolling_avg(length_lr[2]),  linewidth=2, label=learning_rate[2])
ax.plot(rolling_avg(length_lr[3]),  linewidth=2, label=learning_rate[3])

ax.set_title("Episode Length by Episode", fontsize=16)
ax.set_xlabel("Episode", fontsize=14)
ax.set_ylabel("Episode Length", fontsize=14)

ax.grid(True, alpha=0.3)
ax.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %%
r_learning_rate = [0.3, 0.2, 0.1, 0.05]

# %%
rewards = []
length = []
for lr in r_learning_rate:
    agent = SR(
            action_size=7,
            learning_rate=0.3,
            r_learning_rate=lr,
            gamma=0.5, epsilon=0.05, discretizer=discretizer
        )

    rewards_sr = []
    length_sr = []

    for episode in trange(EPISODES):
        obs = env.reset(seed=SEED)
        episodes_length, episodes_rewards = agent.act(env, obs)
        length_sr.append(episodes_length)
        rewards_sr.append(episodes_rewards)
    
    rewards.append(rewards_sr)
    length.append(length_sr)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 16
#      14 for episode in trange(EPISODES):
#      15     obs = env.reset(seed=SEED)
# ---> 16     episodes_length, episodes_rewards = agent.act(env, obs)
#      17     length_sr.append(episodes_length)
#      18     rewards_sr.append(episodes_rewards)
#
# File ~/Documents/Thesis/socnavgym/Code/rl/SR.py:148, in SR.act(self, env, obs, eval)
#     145 action = self.sample_action(state_key, eval=eval)
#     147 # Environment step
# --> 148 next_obs, reward, done, truncated, info = env.step(action)
#     150 # Next state
#     151 next_state_key = self.get_state_key(next_obs)
#
# File ~/miniconda3/envs/socnavgym/lib/python3.11/site-packages/gymnasium/core.py:636, in ActionWrapper.step(self, action)
#     632 def step(
#     633     self, action: WrapperActType
#     634 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     635     """Runs the :attr:`env` :meth:`env.step` using the modified ``action`` from :meth:`self.action`."""
# --> 636     return self.env.step(self.action(action))
#
# File ~/miniconda3/envs/socnavgym/lib/python3.11/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/miniconda3/envs/socnavgym/lib/python3.11/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/miniconda3/envs/socnavgym/lib/python3.11/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/Documents/Thesis/socnavgym/SocNavGym/socnavgym/envs/socnavenv_v1.py:2131, in SocNavEnv_v1.step(self, action_pre)
#    2128 self.handle_collision_and_update()
#    2130 # getting observations
# -> 2131 observation = self._get_obs()
#    2133 # computing rewards and done
#    2134 reward, info = self.compute_reward_and_ticks(action)
#
# File ~/Documents/Thesis/socnavgym/SocNavGym/socnavgym/envs/socnavenv_v1.py:1199, in SocNavEnv_v1._get_obs(self)
#    1197 wall_obs = np.array([], dtype=np.float32)
#    1198 for wall in self.walls:
# -> 1199     obs = self._get_entity_obs(wall)
#    1200     wall_obs = np.concatenate((wall_obs, obs), dtype=np.float32)
#    1201 if self.is_entity_present["walls"]:
#
# File ~/Documents/Thesis/socnavgym/SocNavGym/socnavgym/envs/socnavenv_v1.py:996, in SocNavEnv_v1._get_entity_obs(self, object)
#     994 # if it is a wall, then return the observation
#     995 if object.name == "wall":
# --> 996     return _get_wall_obs(object, self.WALL_SEGMENT_SIZE)
#     998 # initializing output array
#     999 output = np.array([], dtype=np.float32)
#
# File ~/Documents/Thesis/socnavgym/SocNavGym/socnavgym/envs/socnavenv_v1.py:970, in SocNavEnv_v1._get_entity_obs.<locals>._get_wall_obs(wall, size)
#     968 obs = np.concatenate((obs, wall.one_hot_encoding))
#     969 # coorinates of the wall
# --> 970 obs = np.concatenate((obs, self.get_robot_frame_coordinates(np.array([[center[0], center[1]]])).flatten()))
#     971 # sin and cos of relative angles
#     972 obs = np.concatenate((obs, np.array([(np.sin(wall.orientation - self.robot.orientation)), np.cos(wall.orientation - self.robot.orientation)])))
#
# File ~/Documents/Thesis/socnavgym/SocNavGym/socnavgym/envs/socnavenv_v1.py:860, in SocNavEnv_v1.get_robot_frame_coordinates(self, coord)
#     851 """
#     852 Given coordinates in the world frame, this method returns the corresponding robot frame coordinates.
#     853 Args:
#    (...)
#     857
#     858 """
#     859 # converting the coordinates to homogeneous coordinates
# --> 860 homogeneous_coordinates = np.c_[coord, np.ones((coord.shape[0], 1))]
#     861 # getting the robot frame coordinates by multiplying with the transformation matrix
#     862 coord_in_robot_frame = (self.transformation_matrix@homogeneous_coordinates.T).T
#
# File ~/miniconda3/envs/socnavgym/lib/python3.11/site-packages/numpy/lib/_index_tricks_impl.py:346, in AxisConcatenator.__getitem__(self, key)
#     343     self.trans1d = trans1d
#     344     self.ndmin = ndmin
# --> 346 def __getitem__(self, key):
#     347     # handle matrix builder syntax
#     348     if isinstance(key, str):
#     349         frame = sys._getframe().f_back
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1)

ax.plot(length[0],  linewidth=2, label=r_learning_rate[0])
ax.plot(length[1],  linewidth=2, label=r_learning_rate[1])
ax.plot(length[2],  linewidth=2, label=r_learning_rate[2])
ax.plot(length[3],  linewidth=2, label=r_learning_rate[3])

ax.set_title("Episode Length by Episode", fontsize=16)
ax.set_xlabel("Episode", fontsize=14)
ax.set_ylabel("Episode Length", fontsize=14)

ax.grid(True, alpha=0.3)
ax.legend(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
gammas = [0.7, 0.6, 0.5, 0.4]
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
rewards = []
length = []
for gamma in gammas:
    agent = SR(
            action_size=7,
            learning_rate=0.4,
            r_learning_rate=0.2,
            gamma=gamma, epsilon=0.05, discretizer=discretizer
        )

    rewards_sr = []
    length_sr = []

    for episode in trange(EPISODES):
        obs = env.reset(seed=SEED)
        episodes_length, episodes_rewards = agent.act(env, obs)
        length_sr.append(episodes_length)
        rewards_sr.append(episodes_rewards)
    
    rewards.append(rewards_sr)
    length.append(length_sr)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1)

ax.plot(length[0],  linewidth=2, label=gammas[0])
ax.plot(length[1],  linewidth=2, label=gammas[1])
ax.plot(length[2],  linewidth=2, label=gammas[2])
ax.plot(length[3],  linewidth=2, label=gammas[3])

ax.set_title("Episode Length by Episode", fontsize=16)
ax.set_xlabel("Episode", fontsize=14)
ax.set_ylabel("Episode Length", fontsize=14)

ax.grid(True, alpha=0.3)
ax.legend(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
